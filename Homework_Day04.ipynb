# %%
import requests

r = requests.get('https://api.github.com/events')
r.text
# Out:
# '[{"id":"11708658342","type":"CreateEvent","actor":{"id":929485,"login":"gastonstat","display_login":"gastonstat","gravatar_id":"","url":"https://api.github.com/users/gastonstat","avatar_url":"https://avatars.githubusercontent.com/u/929485?"},"repo":{"id":245830086,"name":"gastonstat/warriors-ztest","url":"https://api.github.com/repos/gastonstat/warriors-ztest"},"payload":{"ref":"master","ref_type":"branch","master_branch":"master","description":"Toy experiment with z-test","pusher_type":"user"},"public":true,"created_at":"2020-03-08T14:34:02Z"},{"id":"11708658341","type":"PullRequestReviewCommentEvent","actor":{"id":157728,"login":"phimuemue","display_login":"phimuemue","gravatar_id":"","url":"https://api.github.com/users/phimuemue","avatar_url":"https://avatars.githubusercontent.com/u/157728?"},"repo":{"id":22360263,"name":"rust-itertools/itertools","url":"https://api.github.com/repos/rust-itertools/itertools"},"payload":{"action":"created","comment":{"url":"https://api.github.com/repos/rust-itertools/itertools/pulls/comments/389374392","pull_request_review_id":370834152,"id":389374392,"node_id":"MDI0OlB1bGxSZXF1ZXN0UmV2aWV3Q29tbWVudDM4OTM3NDM5Mg==","diff_hunk":"@@ -0,0 +1,112 @@\\n+use std::fmt;\\n+\\n+/// An iterator to iterate through all the `n`-length combinations in an iterator.\\n+///\\n+/// See [`.unique_combinations()`](../trait.Itertools.html#method.unique_combinations) for moref information.\\n+#[must_use = \\"iterator adaptors are lazy and do nothing unless consumed\\"]\\n+pub struct UniqueCombinations<I: Iterator> {\\n+    len: usize,\\n+    position: Vec<usize>,\\n+    pool: Vec<I::Item>,\\n+    first: bool,\\n+    next_none: bool,\\n+}\\n+\\n+impl<I> fmt::Debug for UniqueCombinations<I>\\n+where\\n+    I: Iterator + fmt::Debug,\\n+    I::Item: fmt::Debug,\\n+{\\n+    debug_fmt_fields!(Combinations, len, position, pool, first);\\n+}\\n+\\n+/// Create a new `UniqueCombinations` from a iterator with clonable and sorable Items.\\n+pub fn unique_combinations<I>(iter: I, len: usize) -> UniqueCombinations<I>\\n+where\\n+    I: Iterator,\\n+    I::Item: Ord,\\n+{\\n+    let mut pool: Vec<_> = iter.collect();\\n+    pool.sort_unstable();\\n+    UniqueCombinations {\\n+        len,\\n+        position: (0..len).collect(),\\n+        pool,\\n+        first: true,\\n+        next_none: false, // only used on iterators with 0 length\\n+    }\\n+}\\n+\\n+impl<I> UniqueCombinations<I>\\n+where\\n+    I: Iterator,\\n+    I::Item: Ord + Clone,\\n+{\\n+    #[inline]\\n+    fn generate(&self) -> Option<Vec<I::Item>> {\\n+        Some(\\n+            self.position\\n+                .iter()\\n+                .map(|n| self.pool[*n].clone())\\n+                .collect(),\\n+        )\\n+    }\\n+}\\n+\\n+impl<I> Iterator for UniqueCombinations<I>\\n+where\\n+    I: Iterator,\\n+    I::Item: Clone + Ord,\\n+{\\n+    type Item = Vec<I::Item>;\\n+    fn next(&mut self) -> Option<Self::Item> {","path":"src/unique_combinations.rs","position":61,"original_position":62,"commit_id":"ed0de3e383e09519cce7eeb6d141e48509771cbe","original_commit_id":"c5e4ed9f0d794c07b800312f06c15e8e2db4e057","user":{"login":"phimuemue","id":157728,"node_id":"MDQ6VXNlcjE1NzcyOA==","avatar_url":"https://avatars3.githubusercontent.com/u/157728?v=4","gravatar_id":"","url":"https://api.github.com/users/phimuemue","html_url":"https://github.com/phimuemue","followers_url":"https://api.github.com/users/phimuemue/followers","following_url":"https://api.github.com/users/phimuemue/following{/other_user}","gists_url":"https://api.github.com/users/phimuemue/gists{/gist_id}","starred_url":"https://api.github.com/users/phimuemue/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/phimuemue/subscriptions","organizations_url":"https://api.github.com/users/phimuemue/orgs","repos_url":"https://api.github.com/users/phimuemue/repos","events_url":"https://api.github.com/users/phimuemue/events{/privacy}","received_events_url":"https://api.github.com/users/phim ...

# %%
import json

json.loads(r.text)
# Out:
# [{'id': '11708658342',
#   'type': 'CreateEvent',
#   'actor': {'id': 929485,
#    'login': 'gastonstat',
#    'display_login': 'gastonstat',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/gastonstat',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/929485?'},
#   'repo': {'id': 245830086,
#    'name': 'gastonstat/warriors-ztest',
#    'url': 'https://api.github.com/repos/gastonstat/warriors-ztest'},
#   'payload': {'ref': 'master',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': 'Toy experiment with z-test',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-03-08T14:34:02Z'},
#  {'id': '11708658341',
#   'type': 'PullRequestReviewCommentEvent',
#   'actor': {'id': 157728,
#    'login': 'phimuemue',
#    'display_login': 'phimuemue',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/phimuemue',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/157728?'},
#   'repo': {'id': 22360263,
#    'name': 'rust-itertools/itertools',
#    'url': 'https://api.github.com/repos/rust-itertools/itertools'},
#   'payload': {'action': 'created',
#    'comment': {'url': 'https://api.github.com/repos/rust-itertools/itertools/pulls/comments/389374392',
#     'pull_request_review_id': 370834152,
#     'id': 389374392,
#     'node_id': 'MDI0OlB1bGxSZXF1ZXN0UmV2aWV3Q29tbWVudDM4OTM3NDM5Mg==',
#     'diff_hunk': '@@ -0,0 +1,112 @@\n+use std::fmt;\n+\n+/// An iterator to iterate through all the `n`-length combinations in an iterator.\n+///\n+/// See [`.unique_combinations()`](../trait.Itertools.html#method.unique_combinations) for moref information.\n+#[must_use = "iterator adaptors are lazy and do nothing unless consumed"]\n+pub struct UniqueCombinations<I: Iterator> {\n+    len: usize,\n+    position: Vec<usize>,\n+    pool: Vec<I::Item>,\n+    first: bool,\n+    next_none: bool,\n+}\n+\n+impl<I> fmt::Debug for UniqueCombinations<I>\n+where\n+    I: Iterator + fmt::Debug,\n+    I::Item: fmt::Debug,\n+{\n+    debug_fmt_fields!(Combinations, len, position, pool, first);\n+}\n+\n+/// Create a new `UniqueCombinations` from a iterator with clonable and sorable Items.\n+pub fn unique_combinations<I>(iter: I, len: usize) -> UniqueCombinations<I>\n+where\n+    I: Iterator,\n+    I::Item: Ord,\n+{\n+    let mut pool: Vec<_> = iter.collect();\n+    pool.sort_unstable();\n+    UniqueCombinations {\n+        len,\n+        position: (0..len).collect(),\n+        pool,\n+        first: true,\n+        next_none: false, // only used on iterators with 0 length\n+    }\n+}\n+\n+impl<I> UniqueCombinations<I>\n+where\n+    I: Iterator,\n+    I::Item: Ord + Clone,\n+{\n+    #[inline]\n+    fn generate(&self) -> Option<Vec<I::Item>> {\n+        Some(\n+            self.position\n+                .iter()\n+                .map(|n| self.pool[*n].clone())\n+                .collect(),\n+        )\n+    }\n+}\n+\n+impl<I> Iterator for UniqueCombinations<I>\n+where\n+    I: Iterator,\n+    I::Item: Clone + Ord,\n+{\n+    type Item = Vec<I::Item>;\n+    fn next(&mut self) -> Option<Self::Item> {',
#     'path': 'src/unique_combinations.rs',
#     'position': 61,
#     'original_position': 62,
#     'commit_id': 'ed0de3e383e09519cce7eeb6d141e48509771cbe',
#     'original_commit_id': 'c5e4ed9f0d794c07b800312f06c15e8e2db4e057',
#     'user': {'login': 'phimuemue',
#      'id': 157728,
#      'node_id': 'MDQ6VXNlcjE1NzcyOA==',
#      'avatar_url': 'https://avatars3.githubusercontent.com/u/157728?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/phimuemue',
#      'html_url': 'https://github.com/phimuemue',
#      'followers_url': 'https://api.github.com/users/phimuemue/followers',
#      'following_url': 'https://api.github.com/users/phimuemue/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/phimuemue/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/phimuemue/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/phimuemue/subscriptions',
#      'organizations_url': 'https://api.github.com/users/phimuemue/orgs',
#      'repos_url': 'https://api.github.com/users/phimuemue/repos',
#      'events_url': 'https://api.github.com/users/phimuemue/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/phimuemue/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': "Hi there! Thanks a lot for bringing the `if`s in line - I really appreciate that and I think it looks better. Also very nice that you got rid of the `done` field.\r\n\r\nI really try to grasp the algorithm and understand the distinct cases. Maybe you can help me with the following questions:\r\n\r\n* Lines 77/78 (`lastpos` and `val`) seem to be analogous to lines 93/94 (`i` and `current`). If this is the case, would it be more readable if we called them the same, used the same logic wrt subtracting 1 from `i`/`lastpos`, and avoided the `mut`ability in the second case?\r\n* Related: Is `for j in lastpos + 1..pool_len {...}` (line 79 and following) analogous to `while next == current` (line 96 and following)? If so, should we implement them in a similar fashion?\r\n\r\nIf all of the above are true:\r\n* Do we then have the situation that the `else`-branch (starting at line 91) is basically a special case (avoiding setting the next one's indices) of the more general case (starting at 75)? If this is the case, would it make sense to leave out this special case (as `Combinations::next` does)?",
#     'created_at': '2020-03-08T14:27:49Z',
#     'updated_at': '2020-03-08T14:34:02Z',
#     'html_url': 'https://github.com/rust-itertools/itertools/pull/363#discussion_r389374392',
#     'pull_request_url': 'https://api.github.com/repos/rust-itertools/itertools/pulls/363',
#     'author_association': 'CONTRIBUTOR',
#     '_links': {'self': {'href': 'https://api.github.com/repos/rust-itertools/itertools/pulls/comments/389374392'},
#      'html': {'href': 'https://github.com/rust-itertools/itertools/pull/363#discussion_r389374392'},
#      'pull_request': {'href': 'https://api.github.com/repos/rust-itertools/itertools/pulls/363'}},
#     'in_reply_to_id': 387246099},
#    'pull_request': {'url': 'https://api.github.com/repos/rust-itertools/itertools/pulls/363',
#     'id': 304076630,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0MzA0MDc2NjMw',
#     'html_url': 'https://github.com/rust-itertools/itertools/pull/363',
#     'diff_url': 'https://github.com/rust-itertools/itertools/pull/363.diff',
#     'patch_url': 'https://github.com/rust-itertools/itertools/pull/363.patch',
#     'issue_url': 'https://api.github.com/repos/rust-itertools/itertools/issues/363',
#     'number': 363,
#     'state': 'open',
#     'locked': False,
#     'title': 'Implement unique_combinations.',
#     'user': {'login': 'meltinglava',
#      'id': 17087998,
#      'node_id': 'MDQ6VXNlcjE3MDg3OTk4',
#      'avatar_url': 'https://avatars3.githubusercontent.com/u/17087998?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/meltinglava',
#      'html_url': 'https://github.com/meltinglava',
#      'followers_url': 'https://api.github.com/users/meltinglava/followers',
#      'following_url': 'https://api.github.com/users/meltinglava/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/meltinglava/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/meltinglava/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/meltinglava/subscriptions',
#      'organizations_url': 'https://api.github.com/users/meltinglava/orgs',
#      'repos_url': 'https://api.github.com/users/meltinglava/repos',
#      'events_url': 'https://api.github.com/users/meltinglava/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/meltinglava/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': 'Some questions that needs to be answared:\r\n* Document differently?\r\n* Any optimalisations?\r\n* The algorithm only requires equal Items to be grouped beside each\r\n  other. This is achived by sorting. However if we there is an\r\n  effisient way to group equals then we can have this require `Eq`\r\n  insted of `Ord`',
#     'created_at': '2019-08-04T15:43:01Z',
#     'updated_at': '2020-03-08T14:34:02Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': 'eaf4fefaf1b4aa351e95e7058a063d47fc1efc51',
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [{'id': 1458019155,
#       'node_id': 'MDU6TGFiZWwxNDU4MDE5MTU1',
#       'url': 'https://api.github.com/repos/rust-itertools/itertools/labels/waiting-on-review',
#       'name': 'waiting-on-review',
#       'color': 'cccccc',
#       'default': False,
#       'description': ''}],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/rust-itertools/itertools/pulls/363/commits',
#     'review_comments_url': 'https://api.github.com/repos/rust-itertools/itertools/pulls/363/comments',
#     'review_comment_url': 'https://api.github.com/repos/rust-itertools/itertools/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/rust-itertools/itertools/issues/363/comments',
#     'statuses_url': 'https://api.github.com/repos/rust-itertools/itertools/statuses/ed0de3e383e09519cce7eeb6d141e48509771cbe',
#     'head': {'label': 'meltinglava:master',
#      'ref': 'master',
#      'sha': 'ed0de3e383e09519cce7eeb6d141e48509771cbe',
#      'user': {'login': 'meltinglava',
#       'id': 17087998,
#       'node_id': 'MDQ6VXNlcjE3MDg3OTk4',
#       'avatar_url': 'https://avatars3.githubusercontent.com/u/17087998?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/meltinglava',
#       'html_url': 'https://github.com/meltinglava',
#       'followers_url': 'https://api.github.com/users/meltinglava/followers',
#       'following_url': 'https://api.github.com/users/meltinglava/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/meltinglava/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/meltinglava/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/meltinglava/subscriptions',
#       'organizations_url': 'https://api.github.com/users/meltinglava/orgs',
#       'repos_url': 'https://api.github.com/users/meltinglava/repos',
#       'events_url': 'https://api.github.com/users/meltinglava/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/meltinglava/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 200507597,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkyMDA1MDc1OTc=',
#       'name': 'itertools',
#       'full_name': 'meltinglava/itertools',
#       'private': False,
#       'owner': {'login': 'meltinglava',
#        'id': 17087998,
#        'node_id': 'MDQ6VXNlcjE3MDg3OTk4',
#        'avatar_url': 'https://avatars3.githubusercontent.com/u/17087998?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/meltinglava',
#        'html_url': 'https://github.com/meltinglava',
#        'followers_url': 'https://api.github.com/users/meltinglava/followers',
#        'following_url': 'https://api.github.com/users/meltinglava/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/meltinglava/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/meltinglava/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/meltinglava/subscriptions',
#        'organizations_url': 'https://api.github.com/users/meltinglava/orgs',
#        'repos_url': 'https://api.github.com/users/meltinglava/repos',
#        'events_url': 'https://api.github.com/users/meltinglava/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/meltinglava/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/meltinglava/itertools',
#       'description': 'Extra iterator adaptors, iterator methods, free functions, and macros.',
#       'fork': True,
#       'url': 'https://api.github.com/repos/meltinglava/itertools',
#       'forks_url': 'https://api.github.com/repos/meltinglava/itertools/forks',
#       'keys_url': 'https://api.github.com/repos/meltinglava/itertools/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/meltinglava/itertools/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/meltinglava/itertools/teams',
#       'hooks_url': 'https://api.github.com/repos/meltinglava/itertools/hooks',
#       'issue_events_url': 'https://api.github.com/repos/meltinglava/itertools/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/meltinglava/itertools/events',
#       'assignees_url': 'https://api.github.com/repos/meltinglava/itertools/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/meltinglava/itertools/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/meltinglava/itertools/tags',
#       'blobs_url': 'https://api.github.com/repos/meltinglava/itertools/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/meltinglava/itertools/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/meltinglava/itertools/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/meltinglava/itertools/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/meltinglava/itertools/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/meltinglava/itertools/languages',
#       'stargazers_url': 'https://api.github.com/repos/meltinglava/itertools/stargazers',
#       'contributors_url': 'https://api.github.com/repos/meltinglava/itertools/contributors',
#       'subscribers_url': 'https://api.github.com/repos/meltinglava/itertools/subscribers',
#       'subscription_url': 'https://api.github.com/repos/meltinglava/itertools/subscription',
#       'commits_url': 'https://api.github.com/repos/meltinglava/itertools/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/meltinglava/itertools/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/meltinglava/itertools/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/meltinglava/itertools/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/meltinglava/itertools/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/meltinglava/itertools/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/meltinglava/itertools/merges',
#       'archive_url': 'https://api.github.com/repos/meltinglava/itertools/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/meltinglava/itertools/downloads',
#       'issues_url': 'https://api.github.com/repos/meltinglava/itertools/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/meltinglava/itertools/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/meltinglava/itertools/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/meltinglava/itertools/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/meltinglava/itertools/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/meltinglava/itertools/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/meltinglava/itertools/deployments',
#       'created_at': '2019-08-04T15:11:38Z',
#       'updated_at': '2020-03-08T12:44:52Z',
#       'pushed_at': '2020-03-08T12:44:49Z',
#       'git_url': 'git://github.com/meltinglava/itertools.git',
#       'ssh_url': 'git@github.com:meltinglava/itertools.git',
#       'clone_url': 'https://github.com/meltinglava/itertools.git',
#       'svn_url': 'https://github.com/meltinglava/itertools',
#       'homepage': 'https://docs.rs/itertools/',
#       'size': 1607,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'Rust',
#       'has_issues': False,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': False,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 0,
#       'license': {'key': 'other',
#        'name': 'Other',
#        'spdx_id': 'NOASSERTION',
#        'url': None,
#        'node_id': 'MDc6TGljZW5zZTA='},
#       'forks': 0,
#       'open_issues': 0,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     'base': {'label': 'rust-itertools:master',
#      'ref': 'master',
#      'sha': 'c83cc48ffe39b96b7c6797b7b31752e840b373bb',
#      'user': {'login': 'rust-itertools',
#       'id': 52889150,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjUyODg5MTUw',
#       'avatar_url': 'https://avatars1.githubusercontent.com/u/52889150?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/rust-itertools',
#       'html_url': 'https://github.com/rust-itertools',
#       'followers_url': 'https://api.github.com/users/rust-itertools/followers',
#       'following_url': 'https://api.github.com/users/rust-itertools/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/rust-itertools/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/rust-itertools/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/rust-itertools/subscriptions',
#       'organizations_url': 'https://api.github.com/users/rust-itertools/orgs',
#       'repos_url': 'https://api.github.com/users/rust-itertools/repos',
#       'events_url': 'https://api.github.com/users/rust-itertools/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/rust-itertools/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 22360263,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkyMjM2MDI2Mw==',
#       'name': 'itertools',
#       'full_name': 'rust-itertools/itertools',
#       'private': False,
#       'owner': {'login': 'rust-itertools',
#        'id': 52889150,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjUyODg5MTUw',
#        'avatar_url': 'https://avatars1.githubusercontent.com/u/52889150?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/rust-itertools',
#        'html_url': 'https://github.com/rust-itertools',
#        'followers_url': 'https://api.github.com/users/rust-itertools/followers',
#        'following_url': 'https://api.github.com/users/rust-itertools/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/rust-itertools/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/rust-itertools/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/rust-itertools/subscriptions',
#        'organizations_url': 'https://api.github.com/users/rust-itertools/orgs',
#        'repos_url': 'https://api.github.com/users/rust-itertools/repos',
#        'events_url': 'https://api.github.com/users/rust-itertools/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/rust-itertools/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/rust-itertools/itertools',
#       'description': 'Extra iterator adaptors, iterator methods, free functions, and macros.',
#       'fork': False,
#       'url': 'https://api.github.com/repos/rust-itertools/itertools',
#       'forks_url': 'https://api.github.com/repos/rust-itertools/itertools/forks',
#       'keys_url': 'https://api.github.com/repos/rust-itertools/itertools/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/rust-itertools/itertools/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/rust-itertools/itertools/teams',
#       'hooks_url': 'https://api.github.com/repos/rust-itertools/itertools/hooks',
#       'issue_events_url': 'https://api.github.com/repos/rust-itertools/itertools/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/rust-itertools/itertools/events',
#       'assignees_url': 'https://api.github.com/repos/rust-itertools/itertools/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/rust-itertools/itertools/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/rust-itertools/itertools/tags',
#       'blobs_url': 'https://api.github.com/repos/rust-itertools/itertools/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/rust-itertools/itertools/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/rust-itertools/itertools/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/rust-itertools/itertools/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/rust-itertools/itertools/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/rust-itertools/itertools/languages',
#       'stargazers_url': 'https://api.github.com/repos/rust-itertools/itertools/stargazers',
#       'contributors_url': 'https://api.github.com/repos/rust-itertools/itertools/contributors',
#       'subscribers_url': 'https://api.github.com/repos/rust-itertools/itertools/subscribers',
#       'subscription_url': 'https://api.github.com/repos/rust-itertools/itertools/subscription',
#       'commits_url': 'https://api.github.com/repos/rust-itertools/itertools/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/rust-itertools/itertools/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/rust-itertools/itertools/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/rust-itertools/itertools/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/rust-itertools/itertools/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/rust-itertools/itertools/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/rust-itertools/itertools/merges',
#       'archive_url': 'https://api.github.com/repos/rust-itertools/itertools/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/rust-itertools/itertools/downloads',
#       'issues_url': 'https://api.github.com/repos/rust-itertools/itertools/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/rust-itertools/itertools/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/rust-itertools/itertools/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/rust-itertools/itertools/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/rust-itertools/itertools/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/rust-itertools/itertools/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/rust-itertools/itertools/deployments',
#       'created_at': '2014-07-28T22:34:37Z',
#       'updated_at': '2020-03-08T02:50:04Z',
#       'pushed_at': '2020-03-08T12:44:51Z',
#       'git_url': 'git://github.com/rust-itertools/itertools.git',
#       'ssh_url': 'git@github.com:rust-itertools/itertools.git',
#       'clone_url': 'https://github.com/rust-itertools/itertools.git',
#       'svn_url': 'https://github.com/rust-itertools/itertools',
#       'homepage': 'https://docs.rs/itertools/',
#       'size': 1577,
#       'stargazers_count': 858,
#       'watchers_count': 858,
#       'language': 'Rust',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': False,
#       'has_pages': False,
#       'forks_count': 145,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 78,
#       'license': {'key': 'other',
#        'name': 'Other',
#        'spdx_id': 'NOASSERTION',
#        'url': None,
#        'node_id': 'MDc6TGljZW5zZTA='},
#       'forks': 145,
#       'open_issues': 78,
#       'watchers': 858,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/rust-itertools/itertools/pulls/363'},
#      'html': {'href': 'https://github.com/rust-itertools/itertools/pull/363'},
#      'issue': {'href': 'https://api.github.com/repos/rust-itertools/itertools/issues/363'},
#      'comments': {'href': 'https://api.github.com/repos/rust-itertools/itertools/issues/363/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/rust-itertools/itertools/pulls/363/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/rust-itertools/itertools/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/rust-itertools/itertools/pulls/363/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/rust-itertools/itertools/statuses/ed0de3e383e09519cce7eeb6d141e48509771cbe'}},
#     'author_association': 'CONTRIBUTOR'}},
#   'public': True,
#   'created_at': '2020-03-08T14:27:49Z',
#   'org': {'id': 52889150,
#    'login': 'rust-itertools',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/rust-itertools',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/52889150?'}},
#  {'id': '11708658334',
#   'type': 'PushEvent',
#   'actor': {'id': 4137960,
#    'login': 'mra00000',
#    'display_login': 'mra00000',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mra00000',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/4137960?'},
#   'repo': {'id': 245124778,
#    'name': 'mra00000/ehospital',
#    'url': 'https://api.github.com/repos/mra00000/ehospital'},
#   'payload': {'push_id': 4734968386,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'a98331f8f82dd673d57b63fbfbe6dcf778b40933',
#    'before': 'ad371da1bfb809ba4e567d34963742021227594b',
#    'commits': [{'sha': 'a98331f8f82dd673d57b63fbfbe6dcf778b40933',
#      'author': {'email': 'mra00000@gmail.com', 'name': 'mra00000'},
#      'message': 'demwebhook event',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/mra00000/ehospital/commits/a98331f8f82dd673d57b63fbfbe6dcf778b40933'}]},
#   'public': True,
#   'created_at': '2020-03-08T14:34:02Z'},
#  {'id': '11708658331',
#   'type': 'GollumEvent',
#   'actor': {'id': 14811066,
#    'login': 'jeanbisutti',
#    'display_login': 'jeanbisutti',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jeanbisutti',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/14811066?'},
#   'repo': {'id': 165139286,
#    'name': 'quick-perf/doc',
#    'url': 'https://api.github.com/repos/quick-perf/doc'},
#   'payload': {'pages': [{'page_name': 'JVM-annotations',
#      'title': 'JVM annotations',
#      'summary': None,
#      'action': 'edited',
#      'sha': 'bf887f9dfe94d180e5ec89f2aad2213adf2dd704',
#      'html_url': 'https://github.com/quick-perf/doc/wiki/JVM-annotations'}]},
#   'public': True,
#   'created_at': '2020-03-08T14:34:02Z'},
#  {'id': '11708658330',
#   'type': 'CreateEvent',
#   'actor': {'id': 41963959,
#    'login': 'aperame',
#    'display_login': 'aperame',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/aperame',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41963959?'},
#   'repo': {'id': 245830193,
#    'name': 'aperame/Linux-Shell-Coding',
#    'url': 'https://api.github.com/repos/aperame/Linux-Shell-Coding'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'master',
#    'description': 'This is a Linux Shell Coding with C language',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-03-08T14:34:02Z'},
#  {'id': '11708658329',
#   'type': 'CreateEvent',
#   'actor': {'id': 33741603,
#    'login': 'PersianBuddy',
#    'display_login': 'PersianBuddy',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/PersianBuddy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/33741603?'},
#   'repo': {'id': 245830194,
#    'name': 'PersianBuddy/TicTacToe',
#    'url': 'https://api.github.com/repos/PersianBuddy/TicTacToe'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'master',
#    'description': "Main steps to write the game's program",
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-03-08T14:34:02Z'},
#  {'id': '11708658326',
#   'type': 'PushEvent',
#   'actor': {'id': 58087975,
#    'login': 'm4vr1g',
#    'display_login': 'm4vr1g',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/m4vr1g',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/58087975?'},
#   'repo': {'id': 223466656,
#    'name': 'm4vr1g/ArchLinuxInstaller',
#    'url': 'https://api.github.com/repos/m4vr1g/ArchLinuxInstaller'},
#   'payload': {'push_id': 4734968382,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '25e7b7bc39c513d55edf285992d9fc033feee967',
#    'before': '359abc0d395e68b44a1ba6130a25d71f79d4a159',
#    'commits': [{'sha': '25e7b7bc39c513d55edf285992d9fc033feee967',
#      'author': {'email': '58087975+m4vr1g@users.noreply.github.com',
#       'name': 'm4vr1g'},
#      'message': 'Update installer.sh',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/m4vr1g/ArchLinuxInstaller/commits/25e7b7bc39c513d55edf285992d9fc033feee967'}]},
#   'public': True,
#   'created_at': '2020-03-08T14:34:02Z'},
#  {'id': '11708658324',
#   'type': 'PushEvent',
#   'actor': {'id': 61352400,
#    'login': 'ksenijam14',
#    'display_login': 'ksenijam14',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ksenijam14',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/61352400?'},
#   'repo': {'id': 244643817,
#    'name': 'ksenijam14/ksenijam14.github.io',
#    'url': 'https://api.github.com/repos/ksenijam14/ksenijam14.github.io'},
#   'payload': {'push_id': 4734968383,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '8abb4750b47fc3a916a8ba49b960d8a897f0526b',
#    'before': '073a62ec3e1afb9b8e1a03712b53539d3cc1072d',
#    'commits': [{'sha': '8abb4750b47fc3a916a8ba49b960d8a897f0526b',
#      'author': {'email': '61352400+ksenijam14@users.noreply.github.com',
#       'name': 'ksenijam14'},
#      'message': 'Update sign_up.html',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/ksenijam14/ksenijam14.github.io/commits/8abb4750b47fc3a916a8ba49b960d8a897f0526b'}]},
#   'public': True,
#   'created_at': '2020-03-08T14:34:02Z'},
#  {'id': '11708658323',
#   'type': 'PushEvent',
#   'actor': {'id': 31575597,
#    'login': 'nishantsharma09',
#    'display_login': 'nishantsharma09',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/nishantsharma09',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/31575597?'},
#   'repo': {'id': 245779389,
#    'name': 'nishantsharma09/girlscript_app',
#    'url': 'https://api.github.com/repos/nishantsharma09/girlscript_app'},
#   'payload': {'push_id': 4734968380,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/girlscript_app_branch1',
#    'head': 'dc3f77b7e1fe9c1e3596b6baf29f3aec483fc720',
#    'before': 'ef203a38bfa79214b3ee8ade226f839f5a553875',
#    'commits': [{'sha': 'dc3f77b7e1fe9c1e3596b6baf29f3aec483fc720',
#      'author': {'email': 'sharma.nishant091996@gmail.com',
#       'name': 'nishantsharma09'},
#      'message': 'Add CONTRIBUTING.md file for the app',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/nishantsharma09/girlscript_app/commits/dc3f77b7e1fe9c1e3596b6baf29f3aec483fc720'}]},
#   'public': True,
#   'created_at': '2020-03-08T14:34:02Z'},
#  {'id': '11708658320',
#   'type': 'PushEvent',
#   'actor': {'id': 47198760,
#    'login': 'yamauchi5748',
#    'display_login': 'yamauchi5748',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/yamauchi5748',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/47198760?'},
#   'repo': {'id': 244641306,
#    'name': 'yamauchi5748/strategyBoard',
#    'url': 'https://api.github.com/repos/yamauchi5748/strategyBoard'},
#   'payload': {'push_id': 4734968378,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/feature/#3ボードを共有できる機能',
#    'head': 'd410015c0a955396111f8613a1deceaf77ccd020',
#    'before': '0393fd376b292af9050a02efcb6f4979ace32caf',
#    'commits': [{'sha': 'd410015c0a955396111f8613a1deceaf77ccd020',
#      'author': {'email': 'kbc17a23@stu.kawahara.ac.jp',
#       'name': 'yamauchi5748'},
#      'message': '[fix]_dockerfile',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/yamauchi5748/strategyBoard/commits/d410015c0a955396111f8613a1deceaf77ccd020'}]},
#   'public': True,
#   'created_at': '2020-03-08T14:34:02Z'},
#  {'id': '11708658315',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 30189103,
#    'login': 'openshift-ci-robot',
#    'display_login': 'openshift-ci-robot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/openshift-ci-robot',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/30189103?'},
#   'repo': {'id': 22442668,
#    'name': 'openshift/origin',
#    'url': 'https://api.github.com/repos/openshift/origin'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/openshift/origin/issues/24542',
#     'repository_url': 'https://api.github.com/repos/openshift/origin',
#     'labels_url': 'https://api.github.com/repos/openshift/origin/issues/24542/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/openshift/origin/issues/24542/comments',
#     'events_url': 'https://api.github.com/repos/openshift/origin/issues/24542/events',
#     'html_url': 'https://github.com/openshift/origin/pull/24542',
#     'id': 565314507,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0Mzc1Mzc4NDk0',
#     'number': 24542,
#     'title': 'Bug 1803077: 4.3: UPSTREAM: 87673: blank out value for unbounded client label',
#     'user': {'login': 'sttts',
#      'id': 730123,
#      'node_id': 'MDQ6VXNlcjczMDEyMw==',
#      'avatar_url': 'https://avatars0.githubusercontent.com/u/730123?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/sttts',
#      'html_url': 'https://github.com/sttts',
#      'followers_url': 'https://api.github.com/users/sttts/followers',
#      'following_url': 'https://api.github.com/users/sttts/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/sttts/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/sttts/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/sttts/subscriptions',
#      'organizations_url': 'https://api.github.com/users/sttts/orgs',
#      'repos_url': 'https://api.github.com/users/sttts/repos',
#      'events_url': 'https://api.github.com/users/sttts/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/sttts/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [{'id': 223051294,
#       'node_id': 'MDU6TGFiZWwyMjMwNTEyOTQ=',
#       'url': 'https://api.github.com/repos/openshift/origin/labels/approved',
#       'name': 'approved',
#       'color': '0ffa16',
#       'default': False,
#       'description': 'Indicates a PR has been approved by an approver from all required OWNERS files.'},
#      {'id': 1393037292,
#       'node_id': 'MDU6TGFiZWwxMzkzMDM3Mjky',
#       'url': 'https://api.github.com/repos/openshift/origin/labels/bugzilla/valid-bug',
#       'name': 'bugzilla/valid-bug',
#       'color': '15dd18',
#       'default': False,
#       'description': 'Indicates that a referenced Bugzilla bug is valid for the branch this PR is targeting.'},
#      {'id': 1394628310,
#       'node_id': 'MDU6TGFiZWwxMzk0NjI4MzEw',
#       'url': 'https://api.github.com/repos/openshift/origin/labels/cherry-pick-approved',
#       'name': 'cherry-pick-approved',
#       'color': 'fef2c0',
#       'default': False,
#       'description': 'Indicates a cherry-pick PR into a release branch has been approved by the release branch manager.'},
#      {'id': 223479084,
#       'node_id': 'MDU6TGFiZWwyMjM0NzkwODQ=',
#       'url': 'https://api.github.com/repos/openshift/origin/labels/lgtm',
#       'name': 'lgtm',
#       'color': '15dd18',
#       'default': False,
#       'description': 'Indicates that a PR is ready to be merged.'},
#      {'id': 640547849,
#       'node_id': 'MDU6TGFiZWw2NDA1NDc4NDk=',
#       'url': 'https://api.github.com/repos/openshift/origin/labels/size/XS',
#       'name': 'size/XS',
#       'color': '009900',
#       'default': False,
#       'description': 'Denotes a PR that changes 0-9 lines, ignoring generated files.'}],
#     'state': 'open',
#     'locked': False,
#     'assignee': {'login': 'mfojtik',
#      'id': 44136,
#      'node_id': 'MDQ6VXNlcjQ0MTM2',
#      'avatar_url': 'https://avatars2.githubusercontent.com/u/44136?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/mfojtik',
#      'html_url': 'https://github.com/mfojtik',
#      'followers_url': 'https://api.github.com/users/mfojtik/followers',
#      'following_url': 'https://api.github.com/users/mfojtik/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/mfojtik/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/mfojtik/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/mfojtik/subscriptions',
#      'organizations_url': 'https://api.github.com/users/mfojtik/orgs',
#      'repos_url': 'https://api.github.com/users/mfojtik/repos',
#      'events_url': 'https://api.github.com/users/mfojtik/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/mfojtik/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'assignees': [{'login': 'mfojtik',
#       'id': 44136,
#       'node_id': 'MDQ6VXNlcjQ0MTM2',
#       'avatar_url': 'https://avatars2.githubusercontent.com/u/44136?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/mfojtik',
#       'html_url': 'https://github.com/mfojtik',
#       'followers_url': 'https://api.github.com/users/mfojtik/followers',
#       'following_url': 'https://api.github.com/users/mfojtik/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/mfojtik/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/mfojtik/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/mfojtik/subscriptions',
#       'organizations_url': 'https://api.github.com/users/mfojtik/orgs',
#       'repos_url': 'https://api.github.com/users/mfojtik/repos',
#       'events_url': 'https://api.github.com/users/mfojtik/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/mfojtik/received_events',
#       'type': 'User',
#       'site_admin': False}],
#     'milestone': None,
#     'comments': 69,
#     'created_at': '2020-02-14T13:03:27Z',
#     'updated_at': '2020-03-08T14:34:02Z',
#     'closed_at': None,
#     'author_association': 'CONTRIBUTOR',
#     'pull_request': {'url': 'https://api.github.com/repos/openshift/origin/pulls/24542',
#      'html_url': 'https://github.com/openshift/origin/pull/24542',
#      'diff_url': 'https://github.com/openshift/origin/pull/24542.diff',
#      'patch_url': 'https://github.com/openshift/origin/pull/24542.patch'},
#     'body': None},
#    'comment': {'url': 'https://api.github.com/repos/openshift/origin/issues/comments/596212071',
#     'html_url': 'https://github.com/openshift/origin/pull/24542#issuecomment-596212071',
#     'issue_url': 'https://api.github.com/repos/openshift/origin/issues/24542',
#     'id': 596212071,
#     'node_id': 'MDEyOklzc3VlQ29tbWVudDU5NjIxMjA3MQ==',
#     'user': {'login': 'openshift-ci-robot',
#      'id': 30189103,
#      'node_id': 'MDQ6VXNlcjMwMTg5MTAz',
#      'avatar_url': 'https://avatars1.githubusercontent.com/u/30189103?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/openshift-ci-robot',
#      'html_url': 'https://github.com/openshift-ci-robot',
#      'followers_url': 'https://api.github.com/users/openshift-ci-robot/followers',
#      'following_url': 'https://api.github.com/users/openshift-ci-robot/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/openshift-ci-robot/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/openshift-ci-robot/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/openshift-ci-robot/subscriptions',
#      'organizations_url': 'https://api.github.com/users/openshift-ci-robot/orgs',
#      'repos_url': 'https://api.github.com/users/openshift-ci-robot/repos',
#      'events_url': 'https://api.github.com/users/openshift-ci-robot/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/openshift-ci-robot/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'created_at': '2020-03-08T14:34:02Z',
#     'updated_at': '2020-03-08T14:34:02Z',
#     'author_association': 'NONE',
#     'body': '@sttts: The following test **failed**, say `/retest` to rerun all failed tests:\n\nTest name | Commit | Details | Rerun command\n--- | --- | --- | ---\nci/prow/e2e-conformance-k8s | 4566543cce967a2f236c3035fb520327585c28fb | [link](https://prow.svc.ci.openshift.org/view/gcs/origin-ci-test/pr-logs/pull/24542/pull-ci-openshift-origin-release-4.3-e2e-conformance-k8s/444) | `/test e2e-conformance-k8s`\n\n[Full PR test history](https://prow.svc.ci.openshift.org/pr-history?org=openshift&repo=origin&pr=24542). [Your PR dashboard](https://prow.svc.ci.openshift.org/pr?query=is:pr+state:open+author:sttts). Please help us cut down on flakes by [linking to](https://github.com/kubernetes/community/blob/master/contributors/devel/flaky-tests.md#filing-issues-for-flaky-tests) an [open issue](https://github.com/openshift/origin/issues?q=is:issue+is:open) when you hit one in your PR.\n\n<details>\n\nInstructions for interacting with me using PR comments are available [here](https://git.k8s.io/community/contributors/guide/pull-requests.md).  If you have questions or suggestions related to my behavior, please file an issue against the [kubernetes/test-infra](https://github.com/kubernetes/test-infra/issues/new?title=Prow%20issue:) repository. I understand the commands that are listed [here](https://go.k8s.io/bot-commands).\n</details>\n<!-- test report -->'}},
#   'public': True,
#   'created_at': '2020-03-08T14:34:02Z',
#   'org': {'id': 792337,
#    'login': 'openshift',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/openshift',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/792337?'}},
#  {'id': '11708658298',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 54345792,
#    'login': 'Maleclypse',
#    'display_login': 'Maleclypse',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Maleclypse',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/54345792?'},
#   'repo': {'id': 5973855,
#    'name': 'CleverRaven/Cataclysm-DDA',
#    'url': 'https://api.github.com/repos/CleverRaven/Cataclysm-DDA'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/CleverRaven/Cataclysm-DDA/issues/38640',
#     'repository_url': 'https://api.github.com/repos/CleverRaven/Cataclysm-DDA',
#     'labels_url': 'https://api.github.com/repos/CleverRaven/Cataclysm-DDA/issues/38640/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/CleverRaven/Cataclysm-DDA/issues/38640/comments',
#     'events_url': 'https://api.github.com/repos/CleverRaven/Cataclysm-DDA/issues/38640/events',
#     'html_url': 'https://github.com/CleverRaven/Cataclysm-DDA/pull/38640',
#     'id': 577498684,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0Mzg1MjY1MjIy',
#     'number': 38640,
#     'title': 'Re-balancing SUS loot spawns specifically in Kitchen area',
#     'user': {'login': 'cupnooodle',
#      'id': 18752867,
#      'node_id': 'MDQ6VXNlcjE4NzUyODY3',
#      'avatar_url': 'https://avatars3.githubusercontent.com/u/18752867?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/cupnooodle',
#      'html_url': 'https://github.com/cupnooodle',
#      'followers_url': 'https://api.github.com/users/cupnooodle/followers',
#      'following_url': 'https://api.github.com/users/cupnooodle/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/cupnooodle/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/cupnooodle/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/cupnooodle/subscriptions',
#      'organizations_url': 'https://api.github.com/users/cupnooodle/orgs',
#      'repos_url': 'https://api.github.com/users/cupnooodle/repos',
#      'events_url': 'https://api.github.com/users/cupnooodle/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/cupnooodle/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 4,
#     'created_at': '2020-03-08T13:11:40Z',
#     'updated_at': '2020-03-08T14:34:01Z',
#     'closed_at': None,
#     'author_association': 'NONE',
#     'pull_request': {'url': 'https://api.github.com/repos/CleverRaven/Cataclysm-DDA/pulls/38640',
#      'html_url': 'https://github.com/CleverRaven/Cataclysm-DDA/pull/38640',
#      'diff_url': 'https://github.com/CleverRaven/Cataclysm-DDA/pull/38640.diff',
#      'patch_url': 'https://github.com/CleverRaven/Cataclysm-DDA/pull/38640.patch'},
# ...
#   'public': True,
#   'created_at': '2020-03-08T14:34:01Z'},
#  {'id': '11708658286',
#   'type': 'PushEvent',
#   'actor': {'id': 48986281,
#    'login': '55577799',
#    'display_login': '55577799',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/55577799',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/48986281?'},
#   'repo': {'id': 245829210,
#    'name': '55577799/For-Future',
#    'url': 'https://api.github.com/repos/55577799/For-Future'},
#   'payload': {'push_id': 4734968352,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '923cc32cf25e1728b92abeb2d873f87f96ebdfbc',
#    'before': 'd7529d22922917bf376d079af52d519b709410f6',
#    'commits': [{'sha': '923cc32cf25e1728b92abeb2d873f87f96ebdfbc',
#      'author': {'email': '55577799@mail.ru', 'name': 'Alena55577799'},
#      'message': 'document replace',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/55577799/For-Future/commits/923cc32cf25e1728b92abeb2d873f87f96ebdfbc'}]},
#   'public': True,
#   'created_at': '2020-03-08T14:34:01Z'},
#  {'id': '11708658281',
#   'type': 'PushEvent',
#   'actor': {'id': 41048102,
#    'login': 'shanghuiyang',
#    'display_login': 'shanghuiyang',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/shanghuiyang',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41048102?'},
#   'repo': {'id': 204147656,
#    'name': 'shanghuiyang/rpi-devices',
#    'url': 'https://api.github.com/repos/shanghuiyang/rpi-devices'},
#   'payload': {'push_id': 4734968349,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '435e2b60392e37ac1e072b480d6739df83dc5a56',
#    'before': 'fe2bf425cc191644edf1431cff1abcf983dbeec8',
#    'commits': [{'sha': '435e2b60392e37ac1e072b480d6739df83dc5a56',
#      'author': {'email': 'shanghui.yang@grabtaxi.com',
#       'name': 'Shanghui Yang'},
#      'message': 'add res',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/shanghuiyang/rpi-devices/commits/435e2b60392e37ac1e072b480d6739df83dc5a56'}]},
#   'public': True,
#   'created_at': '2020-03-08T14:34:01Z'},
#  {'id': '11708658284',
#   'type': 'PushEvent',
#   'actor': {'id': 31420031,
#    'login': 'StudentGiven',
#    'display_login': 'StudentGiven',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/StudentGiven',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/31420031?'},
#   'repo': {'id': 187439339,
#    'name': 'StudentGiven/BookNotes',
#    'url': 'https://api.github.com/repos/StudentGiven/BookNotes'},
#   'payload': {'push_id': 4734968356,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'b8af62f90e925817c0c63312e8415310241fd08f',
#    'before': '6893d5ac77346c155a47e92551b4600041aa82f6',
#    'commits': [{'sha': 'b8af62f90e925817c0c63312e8415310241fd08f',
#      'author': {'email': '31420031+StudentGiven@users.noreply.github.com',
#       'name': 'Jiwen'},
#      'message': 'Create MySQL Ch6.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/StudentGiven/BookNotes/commits/b8af62f90e925817c0c63312e8415310241fd08f'}]},
#   'public': True,
#   'created_at': '2020-03-08T14:34:01Z'},
#  {'id': '11708658279',
#   'type': 'PushEvent',
#   'actor': {'id': 53143045,
#    'login': 'gallinaro',
#    'display_login': 'gallinaro',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/gallinaro',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/53143045?'},
#   'repo': {'id': 245675932,
#    'name': 'gallinaro/economy',
#    'url': 'https://api.github.com/repos/gallinaro/economy'},
#   'payload': {'push_id': 4734968353,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '5279659628987db2cc4e29c06f7d586abce5fcb5',
#    'before': '75b46bc5f36e8a32e90f33df77a64ae83738a3b6',
#    'commits': [{'sha': '5279659628987db2cc4e29c06f7d586abce5fcb5',
#      'author': {'email': 'gally.marco@gmail.com', 'name': 'gallinaro'},
#      'message': 'Update from Forestry.io\ngallinaro updated content/post/Bitcoin/blockchain.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/gallinaro/economy/commits/5279659628987db2cc4e29c06f7d586abce5fcb5'}]},
#   'public': True,
#   'created_at': '2020-03-08T14:34:01Z'},
#  {'id': '11708658287',
#   'type': 'WatchEvent',
#   'actor': {'id': 600604,
#    'login': 'ukautz',
#    'display_login': 'ukautz',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ukautz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/600604?'},
#   'repo': {'id': 7691631,
#    'name': 'moby/moby',
#    'url': 'https://api.github.com/repos/moby/moby'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2020-03-08T14:34:01Z',
#   'org': {'id': 27259197,
#    'login': 'moby',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/moby',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/27259197?'}},
#  {'id': '11708658273',
#   'type': 'PushEvent',
#   'actor': {'id': 37145593,
#    'login': 'yuarasino',
#    'display_login': 'yuarasino',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/yuarasino',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/37145593?'},
#   'repo': {'id': 245604457,
#    'name': 'yuarasino/yuarasino-website',
#    'url': 'https://api.github.com/repos/yuarasino/yuarasino-website'},
#   'payload': {'push_id': 4734968342,
#    'size': 0,
#    'distinct_size': 0,
#    'ref': 'refs/heads/develop',
#    'head': '45fbc999bff198fada832ecfaaeee2ba08264206',
#    'before': '7c13b86b1ba6a8f61e8891578aa0040660da647f',
#    'commits': []},
#   'public': True,
#   'created_at': '2020-03-08T14:34:01Z'},
#  {'id': '11708658269',
#   'type': 'PushEvent',
#   'actor': {'id': 61634733,
#    'login': 'psun2',
#    'display_login': 'psun2',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/psun2',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/61634733?'},
#   'repo': {'id': 245199116,
#    'name': 'psun2/React',
#    'url': 'https://api.github.com/repos/psun2/React'},
#   'payload': {'push_id': 4734968339,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '1cfbe7a762dd39a08c347eab909c8009cf5a4483',
#    'before': '84837f6810c8d65d592ab8fdf2b12e26f1a3c788',
#    'commits': [{'sha': '1cfbe7a762dd39a08c347eab909c8009cf5a4483',
#      'author': {'email': 'tjddjs90_business@naver.com', 'name': '박성언'},
#      'message': 'react 생활코딩',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/psun2/React/commits/1cfbe7a762dd39a08c347eab909c8009cf5a4483'}]},
#   'public': True,
#   'created_at': '2020-03-08T14:34:01Z'},
#  {'id': '11708658268',
#   'type': 'IssuesEvent',
#   'actor': {'id': 8348065,
#    'login': 'epiphyllum',
#    'display_login': 'epiphyllum',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/epiphyllum',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8348065?'},
#   'repo': {'id': 115299192,
#    'name': 'node-pinus/pinus',
#    'url': 'https://api.github.com/repos/node-pinus/pinus'},
#   'payload': {'action': 'opened',
#    'issue': {'url': 'https://api.github.com/repos/node-pinus/pinus/issues/118',
#     'repository_url': 'https://api.github.com/repos/node-pinus/pinus',
#     'labels_url': 'https://api.github.com/repos/node-pinus/pinus/issues/118/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/node-pinus/pinus/issues/118/comments',
#     'events_url': 'https://api.github.com/repos/node-pinus/pinus/issues/118/events',
#     'html_url': 'https://github.com/node-pinus/pinus/issues/118',
#     'id': 577509903,
#     'node_id': 'MDU6SXNzdWU1Nzc1MDk5MDM=',
#     'number': 118,
#     'title': 'sessionService.ts里singleSession这个参数类型是不是应该是boolean?',
#     'user': {'login': 'epiphyllum',
#      'id': 8348065,
#      'node_id': 'MDQ6VXNlcjgzNDgwNjU=',
#      'avatar_url': 'https://avatars1.githubusercontent.com/u/8348065?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/epiphyllum',
#      'html_url': 'https://github.com/epiphyllum',
#      'followers_url': 'https://api.github.com/users/epiphyllum/followers',
#      'following_url': 'https://api.github.com/users/epiphyllum/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/epiphyllum/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/epiphyllum/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/epiphyllum/subscriptions',
#      'organizations_url': 'https://api.github.com/users/epiphyllum/orgs',
#      'repos_url': 'https://api.github.com/users/epiphyllum/repos',
#      'events_url': 'https://api.github.com/users/epiphyllum/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/epiphyllum/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 0,
#     'created_at': '2020-03-08T14:34:01Z',
#     'updated_at': '2020-03-08T14:34:01Z',
#     'closed_at': None,
#     'author_association': 'NONE',
#     'body': '<img width="670" alt="5EE7774FD3C6D256AEDB1C6110D567ED" src="https://user-images.githubusercontent.com/8348065/76164813-d67c2f80-618c-11ea-9fc4-f20d920d357b.png">\r\n\r\n这么定义类型， 程序不会有运行问题， 因为这个变量， 我看在程序里只用来当做bool条件判断。  只是对于看源码的人来说， 不太友好。'}},
#   'public': True,
#   'created_at': '2020-03-08T14:34:01Z',
#   'org': {'id': 34825444,
#    'login': 'node-pinus',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/node-pinus',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/34825444?'}},
#  {'id': '11708658265',
#   'type': 'ReleaseEvent',
#   'actor': {'id': 4662360,
#    'login': 'sbueringer',
#    'display_login': 'sbueringer',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/sbueringer',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/4662360?'},
#   'repo': {'id': 220627102,
#    'name': 'sbueringer/image-builder',
#    'url': 'https://api.github.com/repos/sbueringer/image-builder'},
#   'payload': {'action': 'published',
#    'release': {'url': 'https://api.github.com/repos/sbueringer/image-builder/releases/24326087',
#     'assets_url': 'https://api.github.com/repos/sbueringer/image-builder/releases/24326087/assets',
#     'upload_url': 'https://uploads.github.com/repos/sbueringer/image-builder/releases/24326087/assets{?name,label}',
#     'html_url': 'https://github.com/sbueringer/image-builder/releases/tag/v1.6.2-04',
#     'id': 24326087,
#     'node_id': 'MDc6UmVsZWFzZTI0MzI2MDg3',
#     'tag_name': 'v1.6.2-04',
#     'target_commitish': 'master',
#     'name': 'Release v1.6.2-04',
#     'draft': False,
#     'author': {'login': 'sbueringer',
#      'id': 4662360,
#      'node_id': 'MDQ6VXNlcjQ2NjIzNjA=',
#      'avatar_url': 'https://avatars1.githubusercontent.com/u/4662360?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/sbueringer',
#      'html_url': 'https://github.com/sbueringer',
#      'followers_url': 'https://api.github.com/users/sbueringer/followers',
#      'following_url': 'https://api.github.com/users/sbueringer/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/sbueringer/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/sbueringer/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/sbueringer/subscriptions',
#      'organizations_url': 'https://api.github.com/users/sbueringer/orgs',
#      'repos_url': 'https://api.github.com/users/sbueringer/repos',
#      'events_url': 'https://api.github.com/users/sbueringer/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/sbueringer/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'prerelease': True,
#     'created_at': '2020-03-08T12:58:57Z',
#     'published_at': '2020-03-08T14:34:01Z',
#     'assets': [{'url': 'https://api.github.com/repos/sbueringer/image-builder/releases/assets/18557406',
#       'id': 18557406,
#       'node_id': 'MDEyOlJlbGVhc2VBc3NldDE4NTU3NDA2',
#       'name': 'ubuntu-1910-kube-v1.16.2.qcow2',
#       'label': '',
#       'uploader': {'login': 'sbueringer',
#        'id': 4662360,
#        'node_id': 'MDQ6VXNlcjQ2NjIzNjA=',
#        'avatar_url': 'https://avatars1.githubusercontent.com/u/4662360?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/sbueringer',
#        'html_url': 'https://github.com/sbueringer',
#        'followers_url': 'https://api.github.com/users/sbueringer/followers',
#        'following_url': 'https://api.github.com/users/sbueringer/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/sbueringer/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/sbueringer/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/sbueringer/subscriptions',
#        'organizations_url': 'https://api.github.com/users/sbueringer/orgs',
#        'repos_url': 'https://api.github.com/users/sbueringer/repos',
#        'events_url': 'https://api.github.com/users/sbueringer/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/sbueringer/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'content_type': 'application/zip',
#       'state': 'uploaded',
#       'size': 1439163392,
#       'download_count': 0,
#       'created_at': '2020-03-08T14:28:55Z',
#       'updated_at': '2020-03-08T14:29:20Z',
#       'browser_download_url': 'https://github.com/sbueringer/image-builder/releases/download/v1.6.2-04/ubuntu-1910-kube-v1.16.2.qcow2'},
#      {'url': 'https://api.github.com/repos/sbueringer/image-builder/releases/assets/18557412',
#       'id': 18557412,
#       'node_id': 'MDEyOlJlbGVhc2VBc3NldDE4NTU3NDEy',
#       'name': 'ubuntu-1910-kube-v1.16.2.vmdk',
#       'label': '',
#       'uploader': {'login': 'sbueringer',
#        'id': 4662360,
#        'node_id': 'MDQ6VXNlcjQ2NjIzNjA=',
#        'avatar_url': 'https://avatars1.githubusercontent.com/u/4662360?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/sbueringer',
#        'html_url': 'https://github.com/sbueringer',
#        'followers_url': 'https://api.github.com/users/sbueringer/followers',
#        'following_url': 'https://api.github.com/users/sbueringer/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/sbueringer/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/sbueringer/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/sbueringer/subscriptions',
#        'organizations_url': 'https://api.github.com/users/sbueringer/orgs',
#        'repos_url': 'https://api.github.com/users/sbueringer/repos',
#        'events_url': 'https://api.github.com/users/sbueringer/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/sbueringer/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'content_type': 'application/zip',
#       'state': 'uploaded',
#       'size': 1387009024,
#       'download_count': 0,
#       'created_at': '2020-03-08T14:29:43Z',
#       'updated_at': '2020-03-08T14:30:09Z',
#       'browser_download_url': 'https://github.com/sbueringer/image-builder/releases/download/v1.6.2-04/ubuntu-1910-kube-v1.16.2.vmdk'}],
#     'tarball_url': 'https://api.github.com/repos/sbueringer/image-builder/tarball/v1.6.2-04',
#     'zipball_url': 'https://api.github.com/repos/sbueringer/image-builder/zipball/v1.6.2-04',
#     'body': ''}},
#   'public': True,
#   'created_at': '2020-03-08T14:34:01Z'},
#  {'id': '11708658264',
#   'type': 'CreateEvent',
#   'actor': {'id': 58561319,
#    'login': 'cjxd-bot-test',
#    'display_login': 'cjxd-bot-test',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/cjxd-bot-test',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/58561319?'},
#   'repo': {'id': 245830152,
#    'name': 'cjxd-bot-test/environment-pr-177-74-boot-vault-gke-staging',
#    'url': 'https://api.github.com/repos/cjxd-bot-test/environment-pr-177-74-boot-vault-gke-staging'},
#   'payload': {'ref': 'promote-bdd-spring-1583677735-0.0.1',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-03-08T14:34:01Z'}]

# %%
payload = {'key1': 'value1', 'key2': 'value2'}
r = requests.get("http://httpbin.org/get", params=payload)
json.loads(r.text)
# Out:
# {'args': {'key1': 'value1', 'key2': 'value2'},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.22.0',
#   'X-Amzn-Trace-Id': 'Root=1-5e6503b8-600d89383969301022ce7000'},
#  'origin': '180.204.81.46',
#  'url': 'http://httpbin.org/get?key1=value1&key2=value2'}

# %%
r = requests.post('http://httpbin.org/post', data = {'key':'value'})
json.loads(r.text)
# Out:
# {'args': {},
#  'data': '',
#  'files': {},
#  'form': {'key': 'value'},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate',
#   'Content-Length': '9',
#   'Content-Type': 'application/x-www-form-urlencoded',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.22.0',
#   'X-Amzn-Trace-Id': 'Root=1-5e6503cc-d78ad10097acf9e8a4947a40'},
#  'json': None,
#  'origin': '180.204.81.46',
#  'url': 'http://httpbin.org/post'}

# %%
r = requests.post('http://httpbin.org/post', data = {'key':'value'})
json.loads(r.text)
# Out:
# {'args': {},
#  'data': '',
#  'files': {},
#  'form': {'key': 'value'},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate',
#   'Content-Length': '9',
#   'Content-Type': 'application/x-www-form-urlencoded',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.22.0',
#   'X-Amzn-Trace-Id': 'Root=1-5e6503d9-ce406633905fb7ad59307326'},
#  'json': None,
#  'origin': '180.204.81.46',
#  'url': 'http://httpbin.org/post'}
